# %%
import pandas as pd

# %%
df = pd.read_csv('./csv/15_03_2023/ailey_in_person.csv', index_col=False)

# %%
df
# Out:
#      Start time                                            Sign up  \
# 0  6:00 pm  EDT  /ASP/res_a.asp?tg=12&classId=2146822747&classD...
# 1  6:30 pm  EDT  /ASP/res_a.asp?tg=12&classId=2146822764&classD...
# 2  6:30 pm  EDT  /ASP/res_a.asp?tg=12&classId=2146823140&classD...
# 3  7:00 pm  EDT  /ASP/res_a.asp?tg=12&classId=2146822756&classD...
# 4  7:00 pm  EDT  /ASP/res_a.asp?tg=12&classId=2146823822&classD...
# 5  6:30 pm  EDT  /ASP/res_a.asp?tg=12&classId=2146822749&classD...
# 6  6:30 pm  EDT  /ASP/res_a.asp?tg=12&classId=2146823264&classD...
# 7  7:00 pm  EDT  /ASP/res_a.asp?tg=12&classId=2146822753&classD...
# 8  7:00 pm  EDT  /ASP/res_a.asp?tg=12&classId=2146823178&classD...
#
#                      Class Schedule          Instructor      Studio  \
# 0         IN-STUDIO Beginner Ballet    Benjamin Briones   Studio 1A
# 1         IN-STUDIO Beginner Horton       Amos Machanic   Studio 1C
# 2           IN-STUDIO Zumba Fitness          Mike Gomez   Studio 1B
# ...
