# %%
import pandas as pd

# %%
df = pd.read_csv('./csv/15_03_2023/ailey_in_person.csv', index_col=False)

# %%
left_aligned = df.style.set_properties(**{'text-align': 'left'})

# %%
df['Start time'] = df['Start time'].str.rstrip('  EDT')

# %%
left_aligned
# Out:
# <style type="text/css">
# ...

# %%
df['Class Schedule']
# Out:
# 0           IN-STUDIO Beginner Ballet
# 1           IN-STUDIO Beginner Horton
# 2             IN-STUDIO Zumba Fitness
# 3            IN-STUDIO Beginner Heels
# 4     IN-STUDIO Beginner West African
# 5    IN-STUDIO Beginner Broadway Jazz
# 6              IN-STUDIO Open Hip-Hop
# 7     IN-STUDIO Beginner Contemporary
# 8          IN-STUDIO Beginner Hip-Hop
# Name: Class Schedule, dtype: object

# %%
df['Class Schedule'] = df['Class Schedule'].str.lstrip('IN-STUDIO')

# %%
df
# Out:
#   Start time                                            Sign up  \
# 0    6:00 pm  /ASP/res_a.asp?tg=12&classId=2146822747&classD...
# 1    6:30 pm  /ASP/res_a.asp?tg=12&classId=2146822764&classD...
# 2    6:30 pm  /ASP/res_a.asp?tg=12&classId=2146823140&classD...
# 3    7:00 pm  /ASP/res_a.asp?tg=12&classId=2146822756&classD...
# 4    7:00 pm  /ASP/res_a.asp?tg=12&classId=2146823822&classD...
# 5    6:30 pm  /ASP/res_a.asp?tg=12&classId=2146822749&classD...
# 6    6:30 pm  /ASP/res_a.asp?tg=12&classId=2146823264&classD...
# 7    7:00 pm  /ASP/res_a.asp?tg=12&classId=2146822753&classD...
# 8    7:00 pm  /ASP/res_a.asp?tg=12&classId=2146823178&classD...
#
#             Class Schedule          Instructor      Studio  \
# 0          Beginner Ballet    Benjamin Briones   Studio 1A
# 1          Beginner Horton       Amos Machanic   Studio 1C
# 2            Zumba Fitness          Mike Gomez   Studio 1B
# 3           Beginner Heels   Marie Rose Baramo  Studio LLC
# ...
